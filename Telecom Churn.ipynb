# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telco = pd.read_csv("C:/Users/Som/Downloads/archive (6)/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telco.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telco.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
(telco['Churn'].value_counts()/telco['Churn'].count())*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
telco['Churn'].count()
# Out:
# 7043

# %%
telco.MultipleLines.value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
telco.InternetService.value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
sns.boxplot(telco['tenure'])

# %%
sns.distplot(telco['tenure'])

# %%
sns.boxplot(telco['MonthlyCharges'])

# %%
sns.distplot(telco['MonthlyCharges'])

# %%
telco['TotalCharges'] = telco['TotalCharges'].replace(' ', np.nan)

# %%
telco.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
(telco.isnull().sum()/telco.count())*100
# Out:
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# Partner             0.000000
# Dependents          0.000000
# tenure              0.000000
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.156428
# Churn               0.000000
# dtype: float64

# %%
telco.dropna(inplace=True)

# %%
(telco.isnull().sum()/telco.count())*100
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
telco.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.015683        0.219874
# tenure               0.015683  1.000000        0.246862
# MonthlyCharges       0.219874  0.246862        1.000000

# %%
telco['TotalCharges'] = pd.to_numeric(telco['TotalCharges'])

# %%
sns.heatmap(telco.corr(), annot=True)

# %%
telco['Churn'] = telco['Churn'].map({"Yes":1, "No":0})

# %%
telco.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen        1.000000  0.015683        0.219874      0.102411
# tenure               0.015683  1.000000        0.246862      0.825880
# MonthlyCharges       0.219874  0.246862        1.000000      0.651065
# TotalCharges         0.102411  0.825880        0.651065      1.000000
# Churn                0.150541 -0.354049        0.192858     -0.199484
#
#                    Churn
# SeniorCitizen   0.150541
# tenure         -0.354049
# MonthlyCharges  0.192858
# TotalCharges   -0.199484
# Churn           1.000000

# %%
sns.heatmap(telco.corr(), annot=True)

# %%
sns.distplot(telco['TotalCharges'])

# %%
sns.boxplot(telco['TotalCharges'])

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
plt.figure(figsize = (17, 17))

plt.subplot(5, 3, 1)
sns.countplot('gender', data = telco, hue = 'Churn')

plt.subplot(5, 3, 2)
sns.countplot('PhoneService', data = telco, hue = 'Churn')

plt.subplot(5, 3, 3)
sns.countplot('MultipleLines', data = telco, hue = 'Churn')

plt.subplot(5, 3, 4)
sns.countplot('InternetService', data = telco, hue = 'Churn')

plt.subplot(5, 3, 5)
sns.countplot('OnlineSecurity', data = telco, hue = 'Churn')

plt.subplot(5, 3, 6)
sns.countplot('OnlineBackup', data = telco, hue = 'Churn')

plt.subplot(5, 3, 7)
sns.countplot('DeviceProtection', data = telco, hue = 'Churn')

plt.subplot(5, 3, 8)
sns.countplot('TechSupport', data = telco, hue = 'Churn')

plt.subplot(5, 3, 9)
sns.countplot('StreamingTV', data = telco, hue = 'Churn')

plt.subplot(5, 3, 10)
sns.countplot('StreamingMovies', data = telco, hue = 'Churn')

plt.subplot(5, 3, 11)
sns.countplot('Contract', data = telco, hue = 'Churn')

plt.subplot(5, 3, 12)
sns.countplot('PaperlessBilling', data = telco, hue = 'Churn')

plt.subplot(5, 3, 14)
sns.countplot('Partner', data = telco, hue = 'Churn')

plt.subplot(5, 3, 15)
sns.countplot('Dependents', data = telco, hue = 'Churn')

plt.subplot(5, 3, 13)
sns.countplot('PaymentMethod', data = telco, hue = 'Churn')

plt.xticks(rotation = 45);

# %%
telco[telco['Churn'] == 1].MonthlyCharges.plot(kind = 'hist', alpha = 0.3, color = '#019955', label = 'Churn = Yes')

telco[telco['Churn'] == 0].MonthlyCharges.plot(kind = 'hist', alpha = 0.3, color = '#d89955', label = 'Churn = No')

plt.xlabel('Monthly Charges')
plt.legend();

# %%
telco[telco['Churn'] == 1].TotalCharges.plot(kind = 'hist', alpha = 0.3, color = '#019955', label = 'Churn = Yes')

telco[telco['Churn'] == 0].TotalCharges.plot(kind = 'hist', alpha = 0.3, color = '#d89955', label = 'Churn = No')

plt.xlabel('Total Charges')
plt.grid();
plt.legend();

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder() 
telco['gender']= le.fit_transform(telco['gender'])
telco['PhoneService']= le.fit_transform(telco['PhoneService'])
telco['PaperlessBilling']= le.fit_transform(telco['PaperlessBilling'])
telco['Partner']= le.fit_transform(telco['Partner'])
telco['Dependents']= le.fit_transform(telco['Dependents'])

# %%
telco
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
telco = pd.get_dummies(telco, columns=['MultipleLines'])
telco = pd.get_dummies(telco, columns=['InternetService'])
telco = pd.get_dummies(telco, columns=['OnlineSecurity'])
telco = pd.get_dummies(telco, columns=['OnlineBackup'])
telco = pd.get_dummies(telco, columns=['DeviceProtection'])
telco = pd.get_dummies(telco, columns=['TechSupport'])
telco = pd.get_dummies(telco, columns=['StreamingTV'])
telco = pd.get_dummies(telco, columns=['StreamingMovies'])
telco = pd.get_dummies(telco, columns=['Contract'])
telco = pd.get_dummies(telco, columns=['PaymentMethod'])

# %%
telco
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  ...  \
# ...

# %%
telco = telco.drop("customerID", axis=1)

# %%
telco
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
telco.dtypes
# Out:
# gender                                       int32
# SeniorCitizen                                int64
# Partner                                      int32
# Dependents                                   int32
# tenure                                       int64
# PhoneService                                 int32
# PaperlessBilling                             int32
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# MultipleLines_No                             uint8
# MultipleLines_No phone service               uint8
# MultipleLines_Yes                            uint8
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# OnlineSecurity_No                            uint8
# OnlineSecurity_No internet service           uint8
# ...

# %%
telco
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
telco.corr()
plt.figure(figsize = (30, 30))
sns.heatmap(telco.corr(),vmax=0.8, annot=True)

# %%
pd.DataFrame(telco.corr()['Churn'])
# Out:
#                                             Churn
# gender                                  -0.008545
# SeniorCitizen                            0.150541
# Partner                                 -0.149982
# Dependents                              -0.163128
# tenure                                  -0.354049
# PhoneService                             0.011691
# PaperlessBilling                         0.191454
# MonthlyCharges                           0.192858
# TotalCharges                            -0.199484
# Churn                                    1.000000
# MultipleLines_No                        -0.032654
# MultipleLines_No phone service          -0.011691
# MultipleLines_Yes                        0.040033
# InternetService_DSL                     -0.124141
# InternetService_Fiber optic              0.307463
# InternetService_No                      -0.227578
# OnlineSecurity_No                        0.342235
# OnlineSecurity_No internet service      -0.227578
# ...

# %%
plt.figure(figsize = (7,15))
sns.heatmap(pd.DataFrame(telco.corr()['Churn'].sort_values( ascending=False)), annot=True)

# %%
telco.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'Churn', 'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
# ...

# %%
telco = telco.drop(['StreamingMovies_No internet service','StreamingTV_No internet service','DeviceProtection_No internet service','TechSupport_No internet service','OnlineBackup_No internet service','OnlineSecurity_No internet service'],axis=1)

# %%
telco.corr()
plt.figure(figsize = (30, 30))
sns.heatmap(telco.corr(),vmax=0.8, annot=True)

# %%
churn_corr=telco.corr()[["Churn"]].sort_values("Churn")
corr_drop=list(churn_corr[(churn_corr["Churn"]< 0.05)& (churn_corr["Churn"]>-0.05)].index)
telco.drop(corr_drop,axis=1,inplace=True)

# %%
telco.corr()
plt.figure(figsize = (30, 30))
sns.heatmap(telco.corr(),vmax=0.8, annot=True)

# %%
telco = telco.drop('InternetService_No',axis=1)

# %%
churn_corr=telco.corr()
list(churn_corr[(churn_corr< 0.70)& (churn_corr["Churn"]<0.98)].index)
# Out:
# ['SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PaperlessBilling',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn',
#  'InternetService_DSL',
#  'InternetService_Fiber optic',
#  'OnlineSecurity_No',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No',
#  'OnlineBackup_Yes',
#  'DeviceProtection_No',
#  'DeviceProtection_Yes',
#  'TechSupport_No',
#  'TechSupport_Yes',
#  'StreamingTV_No',
#  'StreamingTV_Yes',
#  'StreamingMovies_No',
#  'StreamingMovies_Yes',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaymentMethod_Bank transfer (automatic)',
#  'PaymentMethod_Credit card (automatic)',
#  'PaymentMethod_Electronic check',
#  'PaymentMethod_Mailed check']

# %%
sns.distplot(telco['MonthlyCharges'])

# %%
sns.distplot(telco['TotalCharges'])

# %%
sns.distplot(telco['MonthlyCharges'])

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            7032 non-null   int64
#  1   Partner                                  7032 non-null   int32
#  2   Dependents                               7032 non-null   int32
#  3   tenure                                   7032 non-null   int64
#  4   PaperlessBilling                         7032 non-null   int32
#  5   MonthlyCharges                           7032 non-null   float64
#  6   TotalCharges                             7032 non-null   float64
#  7   Churn                                    7032 non-null   int64
#  8   InternetService_DSL                      7032 non-null   uint8
#  9   InternetService_Fiber optic              7032 non-null   uint8
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

telco[['tenure','MonthlyCharges','TotalCharges']] = scaler.fit_transform(telco[['tenure','MonthlyCharges','TotalCharges']])

telco.head()
# Out:
#    SeniorCitizen  Partner  Dependents    tenure  PaperlessBilling  \
# 0              0        1           0 -1.280248                 1
# 1              0        0           0  0.064303                 0
# 2              0        0           0 -1.239504                 1
# 3              0        0           0  0.512486                 0
# 4              0        0           0 -1.239504                 1
#
#    MonthlyCharges  TotalCharges  Churn  InternetService_DSL  \
# 0       -1.161694     -0.994194      0                    1
# 1       -0.260878     -0.173740      0                    1
# 2       -0.363923     -0.959649      1                    1
# 3       -0.747850     -0.195248      0                    1
# 4        0.196178     -0.940457      1                    0
#
#    InternetService_Fiber optic  ...  StreamingTV_Yes  StreamingMovies_No  \
# 0                            0  ...                0                   1
# ...

# %%
from sklearn.model_selection import train_test_split

x = telco.drop('Churn', axis=1)
y = telco['Churn']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=100)

# %%
churn1 = (sum(y_test)/len(y_test.index))*100
churn1
# Out:
# 27.582938388625593

# %%
churn2 = (sum(y_train)/len(y_train.index))*100
churn2
# Out:
# 26.147907354733846

# %%
x_train.corr()
plt.figure(figsize = (30, 30))
sns.heatmap(x_train.corr(),vmax=0.8, annot=True)

# %%
import statsmodels.api as sm
model1 = sm.GLM(y_train,(sm.add_constant(x_train)), family = sm.families.Binomial())
print("summary1",model1.fit().summary())
print("summary2",model1.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4901
# Model Family:                Binomial   Df Model:                           20
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2010.4
# Date:                Tue, 15 Dec 2020   Deviance:                       4020.8
# Time:                        19:08:12   Pearson chi2:                 6.07e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop('Partner',1)

# %%
import statsmodels.api as sm
model2 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model2.fit().summary())
print("summary2",model2.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4902
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2010.5
# Date:                Tue, 15 Dec 2020   Deviance:                       4021.0
# Time:                        19:08:13   Pearson chi2:                 6.07e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['TechSupport_Yes','Partner'],1)

# %%
import statsmodels.api as sm
model3 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model3.fit().summary())
print("summary2",model3.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4902
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2010.5
# Date:                Tue, 15 Dec 2020   Deviance:                       4021.0
# Time:                        19:08:14   Pearson chi2:                 6.06e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['TechSupport_Yes','Partner','Dependents'],1)

# %%
import statsmodels.api as sm
model4 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model4.fit().summary())
print("summary2",model4.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4903
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2011.4
# Date:                Tue, 15 Dec 2020   Deviance:                       4022.7
# Time:                        19:08:15   Pearson chi2:                 6.13e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['TechSupport_Yes','Partner','Dependents','OnlineSecurity_Yes'],1)

# %%
import statsmodels.api as sm
model5 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model5.fit().summary())
print("summary2",model5.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4903
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2011.4
# Date:                Tue, 15 Dec 2020   Deviance:                       4022.7
# Time:                        19:08:16   Pearson chi2:                 6.13e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['TechSupport_Yes','Partner','Dependents','OnlineSecurity_Yes','Contract_Month-to-month'],1)

# %%
import statsmodels.api as sm
model6 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model6.fit().summary())
print("summary2",model6.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4903
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2011.4
# Date:                Tue, 15 Dec 2020   Deviance:                       4022.7
# Time:                        19:08:17   Pearson chi2:                 6.13e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['TechSupport_Yes','Partner','Dependents','OnlineSecurity_Yes','Contract_Month-to-month','StreamingTV_No'],1)

# %%
import statsmodels.api as sm
model7 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model7.fit().summary())
print("summary2",model7.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4903
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2011.4
# Date:                Tue, 15 Dec 2020   Deviance:                       4022.7
# Time:                        19:08:18   Pearson chi2:                 6.13e+03
# No. Iterations:                   100
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
x_train = sm.add_constant(x_train[col])

# %%
x_train
# Out:
#       const  SeniorCitizen    tenure  PaperlessBilling  MonthlyCharges  \
# 879     1.0              0  0.023559                 1       -0.337331
# 5790    1.0              0  0.308766                 1       -0.463645
# 6498    1.0              0 -1.280248                 1        0.581767
# 880     1.0              0 -0.913552                 1        1.505852
# 2784    1.0              0 -1.158016                 1        1.106966
# ...     ...            ...       ...               ...             ...
# 79      1.0              0  0.512486                 1       -1.292994
# 3934    1.0              0 -0.913552                 0       -0.815993
# 5964    1.0              0  0.675462                 0       -0.101324
# 6947    1.0              0  1.449597                 1        1.205026
# 5649    1.0              0  0.023559                 0       -1.487450
#
#       TotalCharges  InternetService_DSL  InternetService_Fiber optic  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
model=LR.fit(x_train,y_train)

# %%
y_pred = model.predict(x_train)

# %%
from sklearn import metrics
confusion = metrics.confusion_matrix(y_train, y_pred )
print(confusion)
# Out:
# [[3275  360]
#  [ 588  699]]

# %%
print(metrics.accuracy_score(y_train, y_pred))
# Out:
# 0.8073953677366924

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                                    Features    VIF
# 11                     DeviceProtection_Yes    inf
# 10                      DeviceProtection_No    inf
# 15                      StreamingMovies_Yes    inf
# 5                       InternetService_DSL    inf
# 6               InternetService_Fiber optic    inf
# 14                       StreamingMovies_No    inf
# 8                           OnlineBackup_No    inf
# 9                          OnlineBackup_Yes    inf
# 3                            MonthlyCharges  25.87
# 20           PaymentMethod_Electronic check  21.27
# 21               PaymentMethod_Mailed check  14.32
# 19    PaymentMethod_Credit card (automatic)  14.01
# 18  PaymentMethod_Bank transfer (automatic)  13.84
# 4                              TotalCharges  10.84
# ...

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const'],1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features    VIF
# 6               InternetService_Fiber optic  19.50
# 4                              TotalCharges  10.80
# 5                       InternetService_DSL   8.24
# 1                                    tenure   7.30
# 3                            MonthlyCharges   6.37
# 10                           TechSupport_No   3.64
# 7                         OnlineSecurity_No   3.62
# 14                        Contract_Two year   3.21
# 17           PaymentMethod_Electronic check   3.14
# 9                       DeviceProtection_No   2.97
# 12                       StreamingMovies_No   2.95
# 2                          PaperlessBilling   2.92
# 11                          StreamingTV_Yes   2.86
# 8                           OnlineBackup_No   2.75
# 15  PaymentMethod_Bank transfer (automatic)   2.22
# 16    PaymentMethod_Credit card (automatic)   2.21
# 13                        Contract_One year   1.95
# ...

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const','InternetService_Fiber optic'],1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features    VIF
# 4                              TotalCharges  10.42
# 1                                    tenure   6.73
# 3                            MonthlyCharges   4.78
# 6                         OnlineSecurity_No   3.20
# 9                            TechSupport_No   3.18
# 10                          StreamingTV_Yes   2.85
# 2                          PaperlessBilling   2.69
# 8                       DeviceProtection_No   2.68
# 16           PaymentMethod_Electronic check   2.64
# 7                           OnlineBackup_No   2.50
# 13                        Contract_Two year   2.49
# 11                       StreamingMovies_No   2.40
# 5                       InternetService_DSL   2.03
# 15    PaymentMethod_Credit card (automatic)   1.91
# 14  PaymentMethod_Bank transfer (automatic)   1.89
# 12                        Contract_One year   1.65
# 0                             SeniorCitizen   1.33

# %%
import statsmodels.api as sm
model8 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model8.fit().summary())
print("summary2",model8.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4904
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2017.2
# Date:                Tue, 15 Dec 2020   Deviance:                       4034.5
# Time:                        19:08:19   Pearson chi2:                 5.93e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const','InternetService_Fiber optic','const','TotalCharges'],1)

# %%
import statsmodels.api as sm
model9 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model9.fit().summary())
print("summary2",model9.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4905
# Model Family:                Binomial   Df Model:                           16
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2024.2
# Date:                Tue, 15 Dec 2020   Deviance:                       4048.4
# Time:                        19:08:19   Pearson chi2:                 5.17e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features   VIF
# 5                         OnlineSecurity_No  3.19
# 8                            TechSupport_No  3.17
# 9                           StreamingTV_Yes  2.83
# 2                          PaperlessBilling  2.68
# 7                       DeviceProtection_No  2.67
# 15           PaymentMethod_Electronic check  2.63
# 12                        Contract_Two year  2.49
# 6                           OnlineBackup_No  2.47
# 1                                    tenure  2.41
# 10                       StreamingMovies_No  2.40
# 3                            MonthlyCharges  2.18
# 4                       InternetService_DSL  2.01
# 14    PaymentMethod_Credit card (automatic)  1.91
# 13  PaymentMethod_Bank transfer (automatic)  1.89
# 11                        Contract_One year  1.63
# 0                             SeniorCitizen  1.33

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const','InternetService_Fiber optic','const','TotalCharges',"PaymentMethod_Credit card (automatic)"],1)

# %%
import statsmodels.api as sm
model10 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model10.fit().summary())
print("summary2",model10.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4906
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2024.2
# Date:                Tue, 15 Dec 2020   Deviance:                       4048.5
# Time:                        19:08:19   Pearson chi2:                 5.17e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const','InternetService_Fiber optic','const','TotalCharges',"PaymentMethod_Credit card (automatic)",'DeviceProtection_No'],1)

# %%
import statsmodels.api as sm
model11 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model11.fit().summary())
print("summary2",model11.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4907
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2024.6
# Date:                Tue, 15 Dec 2020   Deviance:                       4049.2
# Time:                        19:08:20   Pearson chi2:                 5.18e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features   VIF
# 5                         OnlineSecurity_No  3.11
# 7                            TechSupport_No  3.03
# 8                           StreamingTV_Yes  2.78
# 2                          PaperlessBilling  2.55
# 6                           OnlineBackup_No  2.43
# 1                                    tenure  2.36
# 11                        Contract_Two year  2.29
# 9                        StreamingMovies_No  2.25
# 3                            MonthlyCharges  2.16
# 13           PaymentMethod_Electronic check  2.05
# 4                       InternetService_DSL  1.96
# 10                        Contract_One year  1.54
# 12  PaymentMethod_Bank transfer (automatic)  1.46
# 0                             SeniorCitizen  1.32

# %%
col = x_train.columns
col = col.drop(['DeviceProtection_Yes','StreamingMovies_Yes','OnlineBackup_Yes','PaymentMethod_Mailed check','const','InternetService_Fiber optic','const','TotalCharges',"PaymentMethod_Credit card (automatic)",'DeviceProtection_No','StreamingMovies_No','const'],1)

# %%
import statsmodels.api as sm
model12 = sm.GLM(y_train,(sm.add_constant(x_train[col])), family = sm.families.Binomial())
print("summary1",model12.fit().summary())
print("summary2",model12.fit().summary2())
# Out:
# summary1                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 4922
# Model:                            GLM   Df Residuals:                     4908
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2024.9
# Date:                Tue, 15 Dec 2020   Deviance:                       4049.8
# Time:                        19:08:20   Pearson chi2:                 5.17e+03
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x_train[col].columns
vif['VIF'] = [variance_inflation_factor(x_train[col].values, i) for i in range(x_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features   VIF
# 5                         OnlineSecurity_No  3.07
# 7                            TechSupport_No  2.84
# 8                           StreamingTV_Yes  2.66
# 2                          PaperlessBilling  2.54
# 6                           OnlineBackup_No  2.39
# 1                                    tenure  2.34
# 10                        Contract_Two year  2.28
# 3                            MonthlyCharges  2.16
# 12           PaymentMethod_Electronic check  2.05
# 4                       InternetService_DSL  1.74
# 9                         Contract_One year  1.54
# 11  PaymentMethod_Bank transfer (automatic)  1.46
# 0                             SeniorCitizen  1.32

# %%
x_train = sm.add_constant(x_train[col])

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
model=LR.fit(x_train,y_train)
y_pred = model.predict(x_train)

# %%
from sklearn import metrics
confusion = metrics.confusion_matrix(y_train, y_pred )
print(confusion)
# Out:
# [[3278  357]
#  [ 592  695]]

# %%
import seaborn as sns
sns.heatmap(confusion, annot=True,fmt='',cmap='Blues')

# %%
print(metrics.accuracy_score(y_train, y_pred))
# Out:
# 0.8071921982933766

# %%
TP = confusion[1,1] #true positive
TN = confusion[0,0] #true negative
FP = confusion[0,1] #false positive
FN = confusion[1,0] #false positive

# %%
#sensitivity
TP/(TP+FN)
# Out:
# 0.54001554001554

# %%
#Specificity
TN/(TN+FP)
# Out:
# 0.9017881705639614

# %%
#false positive rate
FP/(TN+FP)
# Out:
# 0.09821182943603851

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, y_pred,drop_intermediate=False)
roc_auc = metrics.roc_auc_score( y_train, y_pred )
plt.plot(fpr, tpr, 'b',label='ROC curve(area=%0.2f)' % roc_auc)
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.title('AUC ROC curve')
plt.legend(loc='lower right')
plt.show()

# %%
x_test = x_test[col]

# %%
x_test_sm = sm.add_constant(x_test)

# %%
y_test_pred =model.predict(x_test_sm)

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_test_df = pd.DataFrame(y_test)

# %%
y_predt_df = pd.DataFrame(y_test_pred)

# %%
metrics.accuracy_score(y_test_df, y_predt_df)
# Out:
# 0.7924170616113744

# %%
confusion2 = metrics.confusion_matrix(y_test_df, y_predt_df )
confusion2
# Out:
# array([[1356,  172],
#        [ 266,  316]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(confusion2, annot=True,fmt='',cmap='Blues')

# %%
TP = confusion2[1,1] #true positive
TN = confusion2[0,0] #true negative
FP = confusion2[0,1] #false positive
FN = confusion2[1,0] #false positive

# %%
#sensitivity
TP/(TP+FN)
# Out:
# 0.5429553264604811

# %%
#Specificity
TN/(TN+FP)
# Out:
# 0.887434554973822

# %%
#false positive rate
FP/(TN+FP)
# Out:
# 0.112565445026178

# %%
x_train = x_train.drop('const', axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DTmodel=DT.fit(x_train,y_train)
y_pred2 = DTmodel.predict(x_train)

# %%
print(metrics.accuracy_score(y_train, y_pred2))
# Out:
# 0.9947175944737912

# %%
y_test_pred2 = DTmodel.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, y_test_pred2))
# Out:
# 0.7199052132701422

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RFmodel=RF.fit(x_train,y_train)
y_pred3 = RFmodel.predict(x_train)

# %%
print(metrics.accuracy_score(y_train, y_pred3))
# Out:
# 0.9945144250304754

# %%
y_test_pred3 = RFmodel.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, y_test_pred3))
# Out:
# 0.7682464454976303

# %%
from sklearn.neighbors import KNeighborsClassifier
KN = KNeighborsClassifier()
KNmodel=KN.fit(x_train,y_train)
y_pred4 = KNmodel.predict(x_train)

# %%
print(metrics.accuracy_score(y_train, y_pred4))
# Out:
# 0.8459975619666802

# %%
y_test_pred4 = KNmodel.predict(x_test)

# %%
print(metrics.accuracy_score(y_test, y_test_pred4))
# Out:
# 0.7635071090047393
